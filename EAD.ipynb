# %% [raw]
# The purpose of this project is to conduct exploratory data analysis on the data set and perform EDA on this data with the aim of learning more about the variables.

# %%
# Import packages and libraries

import numpy as np
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load dataset into dataframe
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
df.size
# Out:
# 408582

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %% [raw]
# Boxplots check for outliers on relevant columns such as trip distance and trip duration

# %%
# Convert data columns to datetime

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %% [raw]
# trip distance

# %%
# Box plot of trip_distance

plt.figure(figsize=(7,2))
plt.title('trip_distance')
sns.boxplot(data=None, x = df['trip_distance'], fliersize = 1)
# Out:
# <Axes: title={'center': 'trip_distance'}, xlabel='trip_distance'>

# %%
# Histogram of trip_distance

plt.figure(figsize=(10,5))
sns.histplot(df['trip_distance'], bins=range(0,26,1))
plt.title('Trip distance histogram')
# Out:
# Text(0.5, 1.0, 'Trip distance histogram')

# %% [raw]
# total amount

# %%
# Box plot of total_amount

plt.figure(figsize=(7,2))
plt.title('total_amount')
sns.boxplot(data=None, x = df['total_amount'], fliersize = 1)
# Out:
# <Axes: title={'center': 'total_amount'}, xlabel='total_amount'>

# %%
# Histogram of total_amount

plt.figure(figsize=(10,5))
ax = sns.histplot(df['total_amount'], bins=range(-10,101,5))
ax.set_xticks(range(-10,101,5))
ax.set_xticklabels(range(-10,101,5))
plt.title('Total amount histogram')
# Out:
# Text(0.5, 1.0, 'Total amount histogram')

# %% [raw]
# tip amount

# %%
# Box plot of tip_amount

plt.figure(figsize=(7,2))
plt.title('tip_amount')
sns.boxplot(data=None, x = df['tip_amount'], fliersize = 1)
# Out:
# <Axes: title={'center': 'tip_amount'}, xlabel='tip_amount'>

# %%
# Histogram of tip_amount

plt.figure(figsize=(10,5))
ax = sns.histplot(df['tip_amount'], bins=range(0,21,1))
ax.set_xticks(range(0,21,1))
ax.set_xticklabels(range(0,21,1))
plt.title('Total tip histogram')
# Out:
# Text(0.5, 1.0, 'Total tip histogram')

# %% [raw]
# tip_amount by vendor

# %%
# Histogram of tip_amount by vendor

plt.figure(figsize=(10,5))
ax = sns.histplot(data=df, x='tip_amount', 
                  bins=range(0,21,1),
                  hue = 'VendorID',
                  multiple='stack',
                  palette = 'pastel')
ax.set_xticks(range(0,21,1))
ax.set_xticklabels(range(0,21,1))
plt.title('Total tip histogram')
# Out:
# Text(0.5, 1.0, 'Total tip histogram')

# %%
# Histogram of tip_amount by vendor for tips > $10 

tips = df[df['tip_amount'] > 10]
plt.figure(figsize=(10,5))
ax = sns.histplot(data=tips, x='tip_amount', 
                  bins=range(10,21,1),
                  hue = 'VendorID',
                  multiple='stack',
                  palette = 'pastel')
ax.set_xticks(range(10,21,1))
ax.set_xticklabels(range(10,21,1))
plt.title('Total tip histogram')
# Out:
# Text(0.5, 1.0, 'Total tip histogram')

# %% [raw]
# Mean tips by passenger count

# %%
df['passenger_count'].value_counts()
# Out:
# 1    16117
# 2     3305
# 5     1143
# 3      953
# 6      693
# 4      455
# 0       33
# Name: passenger_count, dtype: int64

# %%
# Mean tips by passenger_count

mean_tips_by_passenger_count = df.groupby(['passenger_count']).mean()[['tip_amount']]
mean_tips_by_passenger_count
# Out:
# /var/folders/4j/tj4fjk0155n81rl7r2yb7g_00000gn/T/ipykernel_12824/2835357875.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_tips_by_passenger_count = df.groupby(['passenger_count']).mean()[['tip_amount']]
#                  tip_amount
# passenger_count
# 0                  2.135758
# 1                  1.848920
# 2                  1.856378
# 3                  1.716768
# 4                  1.530264
# 5                  1.873185
# 6                  1.720260

# %%
# Bar plot for mean tips by passenger count

data = mean_tips_by_passenger_count.tail(-1)
sns.barplot(x=data.index, y=data['tip_amount'])
# Out:
# <Axes: xlabel='passenger_count', ylabel='tip_amount'>

# %% [raw]
# Create month and day columns

# %%
# Month column

df['Month'] = df['tpep_pickup_datetime'].dt.month_name()

# Day column

df['Day'] = df['tpep_pickup_datetime'].dt.day_name()
df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0    24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1    35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2   106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3    38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4    30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# ...

# %% [raw]
# ride count by month

# %%
# Total number of rides for each month

monthly_rides = df['Month'].value_counts()
monthly_rides
# Out:
# March        2049
# October      2027
# April        2019
# May          2013
# January      1997
# June         1964
# December     1863
# November     1843
# February     1769
# September    1734
# August       1724
# July         1697
# Name: Month, dtype: int64

# %%
# Reorder the monthly ride list so months go in order

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
         'August', 'September', 'October', 'November', 'December']

monthly_rides = monthly_rides.reindex(index=month_order)
monthly_rides
# Out:
# January      1997
# February     1769
# March        2049
# April        2019
# May          2013
# June         1964
# July         1697
# August       1724
# September    1734
# October      2027
# November     1843
# December     1863
# Name: Month, dtype: int64

# %%
# Bar plot of total rides per month

plt.figure(figsize=(12,7))
sns.barplot(x=monthly_rides.index, y=monthly_rides)
# Out:
# <Axes: ylabel='Month'>

# %% [raw]
# total ride count by day

# %%
# Time for rides by day

day_rides = df['Day'].value_counts()
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_rides = day_rides.reindex(index=day_order)
day_rides
# Out:
# Monday       2931
# Tuesday      3198
# Wednesday    3390
# Thursday     3402
# Friday       3413
# Saturday     3367
# Sunday       2998
# Name: Day, dtype: int64

# %%
# Bar plot for ride count by day

plt.figure(figsize=(12,7))
sns.barplot(x=day_rides.index, y=day_rides)
# Out:
# <Axes: ylabel='Day'>

# %% [raw]
# total revenue by day of the week

# %%
# Total revenue by day

day_rev = df.groupby(['Day']).sum()[['total_amount']]
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_rev = day_rev.reindex(index=day_order)
day_rev
# Out:
# /var/folders/4j/tj4fjk0155n81rl7r2yb7g_00000gn/T/ipykernel_12824/1417176704.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day_rev = df.groupby(['Day']).sum()[['total_amount']]
#            total_amount
# Day
# Monday         49574.37
# Tuesday        52527.14
# Wednesday      55310.47
# Thursday       57181.91
# Friday         55818.74
# Saturday       51195.40
# Sunday         48624.06

# %%
# Bar plot of total revenue by day

plt.figure(figsize=(12,7))
sns.barplot(x=day_rev.index, y=day_rev['total_amount'])
# Out:
# <Axes: xlabel='Day', ylabel='total_amount'>

# %% [raw]
# Total revenue by month

# %%
# Total revenue by month

month_rev = df.groupby(['Month']).sum()[['total_amount']]
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
         'August', 'September', 'October', 'November', 'December']
month_rev = month_rev.reindex(index=month_order)
month_rev
# Out:
# /var/folders/4j/tj4fjk0155n81rl7r2yb7g_00000gn/T/ipykernel_12824/3860920209.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   month_rev = df.groupby(['Month']).sum()[['total_amount']]
#            total_amount
# Month
# January        31735.25
# February       28937.89
# March          33085.89
# April          32012.54
# May            33828.58
# June           32920.52
# July           26617.64
# August         27759.56
# September      28206.38
# October        33065.83
# November       30800.44
# December       31261.57

# %%
# Bar plot of total revenue by month

plt.figure(figsize=(12,7))
ax = sns.barplot(x=month_rev.index, y=month_rev['total_amount'])

# %% [raw]
# Scatter plot

# %% [raw]
# mean trip distance by drop-off location

# %%
# Number of unique drop-off location IDs

df['DOLocationID'].nunique()
# Out:
# 216

# %%
# Mean trip distance for each drop-off location
distance_by_dropoff = df.groupby('DOLocationID').mean()[['trip_distance']]
distance_by_dropoff = distance_by_dropoff.sort_values(by='trip_distance')
distance_by_dropoff
# Out:
# /var/folders/4j/tj4fjk0155n81rl7r2yb7g_00000gn/T/ipykernel_12824/3710832341.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   distance_by_dropoff = df.groupby('DOLocationID').mean()[['trip_distance']]
#               trip_distance
# DOLocationID
# 207                1.200000
# 193                1.390556
# 237                1.555494
# 234                1.727806
# 137                1.818852
# ...                     ...
# 51                17.310000
# 11                17.945000
# 210               20.500000
# 29                21.650000
# 23                24.275000
#
# [216 rows x 1 columns]

# %%
# Bar plot of mean trip distances by drop-off location in ascending order by distance

plt.figure(figsize=(14,6))
ax = sns.barplot(x=distance_by_dropoff.index, 
                 y=distance_by_dropoff['trip_distance'],
                 order=distance_by_dropoff.index)
ax.set_xticklabels([])
ax.set_xticks([])
plt.title('Mean trip distance by drop-off location', fontsize=16);

# %% [raw]
# Histogram of rides by drop-off location

# %%
plt.figure(figsize=(16,4))
# DOLocationID column is numeric, so sort in ascending order
sorted_dropoffs = df['DOLocationID'].sort_values()
# Convert to string
sorted_dropoffs = sorted_dropoffs.astype('str')
# Plot
sns.histplot(sorted_dropoffs, bins=range(0, df['DOLocationID'].max()+1, 1))
plt.xticks([])
plt.xlabel('Drop-off locations')
plt.title('Histogram of rides by drop-off location', fontsize=16);
